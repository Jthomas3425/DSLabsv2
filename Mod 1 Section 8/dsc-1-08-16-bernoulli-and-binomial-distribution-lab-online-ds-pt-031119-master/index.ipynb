# %% [markdown]
# # Bernoulli and Binomial Distribution - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll practice your newly gained knowledge on the Bernoulli and Binomial Distribution.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Apply the formulas for the Binomial and Bernoulli distribution
# * Apply NumPy to randomly generate Binomial and Bernoulli trials
# * Use Matplotlib to generate Binomial and Bernoulli trials with various probabilities

# %% [markdown]
# ## Apply the formulas for the Binomial and Bernoulli distribution

# %% [markdown]
# When playing a game of bowling, what is the probability of throwing exactly 3 strikes in a game with 10 rounds? Assume that the probability of throwing a strike is 25% for each round. Use the formula for the Binomial distribution to get to the answer. You've created this before, so we provide you with the function for factorials again:

# %%
def factorial(n):
    prod = 1
    while n >= 1:
        prod = prod * n
        n = n - 1
    return prod

# %%
p_3_strikes = (factorial(10))/(factorial(7)*factorial(3))*((0.25**3)*(0.75**7)) #answer = 0.2502822
p_3_strikes
# Out:
# 0.25028228759765625

# %% [markdown]
# Now, create a function for the Binomial distribution with three arguments $n$, $p$ and $k$ just like in the formula.

# %%
def binom_distr(n,p,k):
    binom = factorial(n)/(factorial(k)*factorial(n-k))*p**k*(1-p)**(n-k)
            #(Counting the probability space) * (#Probability of Success ^ Number of Chances) ^ (#Probability of Failure() ^ Number of failure chances(Total sample space - Number of Successful Outcomes)
    return binom

# %% [markdown]
# Validate your previous result applying your new function.

# %%
binom_distr(10,0.25,3)
# Out:
# 0.25028228759765625

# %% [markdown]
# Now write a for loop along with your function to compute the probability that you have five strikes or more in one game. You'll want to use numpy here!

# %%
import numpy as np
prob = 0
for x in np.arange(5,11):
    prob += binom_distr(10,0.25,x)
    print(f'Probability:{prob}')
# Out:
# Probability:0.058399200439453125
# Probability:0.07462120056152344
# Probability:0.07771110534667969
# Probability:0.07809734344482422
# Probability:0.0781259536743164
# Probability:0.07812690734863281

# %% [markdown]
# ## Use a simulation to get the probabilities for all the potential outcomes

# %% [markdown]
# Repeat the experiment 5000 times.

# %%
# leave the random seed here 
#np.random.seed(123)
prob = 0
i = 5000
iteration = []
for x in range(i):
    iteration.append(np.random.binomial(10,0.25))
    expr = np.array(iteration)
    print(expr)
# Out:
# [3]
# [3 1]
# [3 1 4]
# [3 1 4 3]
# [3 1 4 3 2]
# [3 1 4 3 2 3]
# [3 1 4 3 2 3 2]
# [3 1 4 3 2 3 2 4]
# [3 1 4 3 2 3 2 4 3]
# [3 1 4 3 2 3 2 4 3 4]
# [3 1 4 3 2 3 2 4 3 4 3]
# [3 1 4 3 2 3 2 4 3 4 3 1]
# [3 1 4 3 2 3 2 4 3 4 3 1 3]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3 5]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3 5 4]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3 5 4 2]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3 5 4 2 4]
# [3 1 4 3 2 3 2 4 3 4 3 1 3 4 4 2 3 3 2 1 5 5 3 3 5 4 2 4 4]
# ...

# %%
# the results should look like this:
# [0 1 2 3 4 5 6 7 8]
# [ 310  941 1368 1286  707  297   78   11    2]
values, counts = np.unique(expr, return_counts=True)
print(values)
print(counts)
# Out:
# [0 1 2 3 4 5 6 7]
# [ 247 1006 1349 1311  714  279   85    9]

# %% [markdown]
# ## Visualize these results

# %% [markdown]
# Make sure to set an appropriate title and appropriate y-axis label

# %%
import matplotlib.pyplot as plt

plt.figure(1,figsize=(10,4))
plt.bar(values,counts/5000) #Can count the number of occurrences or counts/number of trials for percentage
plt.show()

# %% [markdown]
# You can see that, with a 25% strike hit rate, even when simulating 5000 times, an almost perfect and perfect game of 9 and 10 strikes didn't even occur once! If you change your seed, however, you'll see that occasionally perfect games will show up randomly.

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you practiced your newly gained knowledge on the Bernoulli and Binomial Distribution.
