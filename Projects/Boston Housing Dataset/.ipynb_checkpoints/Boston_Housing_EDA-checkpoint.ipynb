# %%
#Import Libraries and the data
# %matplotlib inline
import pandas as pd
bh_data = pd.read_csv('train.csv')
bh_data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
#Data Dictionary

#crim: per capita crime rate by town.
#zn: proportion of residential land zoned for lots over 25,000 sq.ft.
#indus: proportion of non-retail business acres per town.
#chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#nox: nitrogen oxides concentration (parts per 10 million).
#rm: average number of rooms per dwelling.
#age: proportion of owner-occupied units built prior to 1940.
#dis: weighted mean of distances to five Boston employment centres.
#rad: index of accessibility to radial highways.
#tax: full-value property-tax rate per $10,000.
#ptratio: pupil-teacher ratio by town.
#black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#lstat: lower status of the population (percent).
#medv: median value of owner-occupied homes in $10000s.

# %%
#Figures relating to Industry/Nox of area
#figure = plt.figure()
#indus_nox = figure.add_subplot(121)
#indus_nox = pd.DataFrame({'Industry Var': bh_data.loc[:,'indus'], 'Nitrogen Oxide' : bh_data.loc[:,'nox']})
#indus_nox.plot('Nitrogen Oxide','Industry Var',kind='scatter',figsize=(20,8))

#river_bounds = len(bh_data.loc[(bh_data['chas'] == 1)])
#out_of_river_bounds = len(bh_data.loc[(bh_data['chas'] == 0)])

river = pd.DataFrame({'River vs Non-River' : [len(bh_data.loc[(bh_data['chas'] == 0)]), len(bh_data.loc[(bh_data['chas'] == 1)])]})
river.plot(y='River vs Non-River', kind='pie')
#Could update the 0 and 1's to True/False in the 'chas' Column

crime_hvalue = pd.DataFrame({'Crime': bh_data.loc[:,'crim'], 'Property Value': bh_data.loc[:,'medv']})
crime_hvalue.plot('Crime', 'Property Value', kind='scatter', figsize=(10,8))
#Wondering why 'blacks' is calculated as described above?

# %%
#Taking a look at the data using a scatter matrix to determine correlations.
pd.plotting.scatter_matrix(bh_data,figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023F3C7E2080>,
# ...
#       dtype=object)
